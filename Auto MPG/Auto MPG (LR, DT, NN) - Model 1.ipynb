# %% [markdown]
# ## Models for  Auto MPG Data set
#
# ###  Model 1 (as in Kaggle.com)
#
# - missing values for `horsepower` replaced with mean of `horsepower`.
# - all columns are numbers.

# %% [markdown]
# ## Import libraries/packages

# %%
### General libraries ###
import pandas as pd
from pandas.api.types import CategoricalDtype
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import plotly.figure_factory as ff
import seaborn as sns
import numpy as np
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

##################################

### ML Models ###
from sklearn.linear_model import LinearRegression
from sklearn import tree
# from sklearn.tree import export_text
from sklearn.neural_network import MLPRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import StandardScaler

##################################

### Metrics ###
from sklearn import metrics
from sklearn.model_selection import cross_validate
from sklearn.metrics import f1_score,confusion_matrix, mean_squared_error, mean_absolute_error, classification_report, roc_auc_score, roc_curve, precision_score, recall_score

# %% [markdown]
# ## Part 1: Load and clean the data

# %%
# Read the data from the auto-mpg_data-original.csv file.
ds = pd.read_csv("auto-mpg_data-original.csv")

# %%
# Examine the data types and the number of non-null items.
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 406 entries, 0 to 405
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     406 non-null    float64
#  2   displacement  406 non-null    float64
#  3   horsepower    400 non-null    float64
#  4   weight        406 non-null    float64
#  5   acceleration  406 non-null    float64
#  6   model year    406 non-null    float64
#  7   origin        406 non-null    float64
#  8   car name      406 non-null    object
# dtypes: float64(8), object(1)
# memory usage: 28.7+ KB

# %%
# Display the shape of the data.
print("The data frame has {} rows and {} columns.".format(
    ds.shape[0], ds.shape[1]))
# Out:
# The data frame has 406 rows and 9 columns.

# %%
# Statistics for the data set.
ds.describe().transpose()
# Out:
#               count         mean         std     min      25%     50%  \
# mpg           398.0    23.514573    7.815984     9.0    17.50    23.0
# cylinders     406.0     5.475369    1.712160     3.0     4.00     4.0
# displacement  406.0   194.779557  104.922458    68.0   105.00   151.0
# horsepower    400.0   105.082500   38.768779    46.0    75.75    95.0
# weight        406.0  2979.413793  847.004328  1613.0  2226.50  2822.5
# acceleration  406.0    15.519704    2.803359     8.0    13.70    15.5
# model year    406.0    75.921182    3.748737    70.0    73.00    76.0
# origin        406.0     1.568966    0.797479     1.0     1.00     1.0
#
#                    75%     max
# mpg             29.000    46.6
# cylinders        8.000     8.0
# displacement   302.000   455.0
# horsepower     130.000   230.0
# weight        3618.250  5140.0
# acceleration    17.175    24.8
# model year      79.000    82.0
# origin           2.000     3.0

# %%
sns.pairplot(ds.drop(['cylinders','origin','model year','car name'], axis=1),diag_kind='kde')

# %%
sns.set(context='notebook', style='whitegrid',
        font='sans-serif', font_scale=1.3)

f, axes = plt.subplots(2, 3, figsize=(20, 20), facecolor='white')
# f.suptitle('FREQUENCY OF CATEGORICAL VARIABLES (BY TARGET)')
ax1 = sns.violinplot(ds['mpg'],  palette="Set1", ax=axes[0, 0])
ax2 = sns.violinplot(ds['displacement'], palette="Set2", ax=axes[0, 1])
ax3 = sns.violinplot(ds['horsepower'], palette="Set3", ax=axes[0, 2])
ax4 = sns.violinplot(ds['weight'], palette="Set2", ax=axes[1, 0])
ax5 = sns.violinplot(ds['acceleration'], palette="Set3", ax=axes[1, 1])
ax6 = sns.violinplot(ds['cylinders'], palette="Set1", ax=axes[1, 2])

# %%
# Check for duplicate rows.
print(f"There are {ds.duplicated().sum()} duplicate rows in the data set.")
# Out:
# There are 0 duplicate rows in the data set.

# %%
# Number of null values for each attribute.
ds.isnull().sum()
# Out:
# mpg             8
# cylinders       0
# displacement    0
# horsepower      6
# weight          0
# acceleration    0
# model year      0
# origin          0
# car name        0
# dtype: int64

# %% [markdown]
# The rows with a null value from the `mpg` attribute can be seen below:

# %%
# Rows with null value at the "mpg" column.
ds[ds['mpg'].isnull()]
# Out:
#      mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 10   NaN        4.0         133.0       115.0  3090.0          17.5
# 11   NaN        8.0         350.0       165.0  4142.0          11.5
# 12   NaN        8.0         351.0       153.0  4034.0          11.0
# 13   NaN        8.0         383.0       175.0  4166.0          10.5
# 14   NaN        8.0         360.0       175.0  3850.0          11.0
# 17   NaN        8.0         302.0       140.0  3353.0           8.0
# 39   NaN        4.0          97.0        48.0  1978.0          20.0
# 367  NaN        4.0         121.0       110.0  2800.0          15.4
#
#      model year  origin                          car name
# 10         70.0     2.0              citroen ds-21 pallas
# 11         70.0     1.0  chevrolet chevelle concours (sw)
# 12         70.0     1.0                  ford torino (sw)
# 13         70.0     1.0           plymouth satellite (sw)
# 14         70.0     1.0                amc rebel sst (sw)
# 17         70.0     1.0             ford mustang boss 302
# 39         71.0     2.0       volkswagen super beetle 117
# 367        81.0     2.0                         saab 900s

# %% [markdown]
# The above rows provide no usefull information because the class attribute value is missing. Hence, we cannot use them as a training nor a test set for our model, so they will be removed them from the dataset. For now, we store them for a potential future use.

# %%
# Store rows with a missing value at "mpg" attribute as a prediction set for future use.
prediction_set = ds[ds['mpg'].isnull()].drop('mpg', axis=1)

# %% [markdown]
# The rows with null values in the `horsepower` column can be seen below:

# %%
# Rows with null value at the "horsepower" column.
ds[ds['horsepower'].isnull()]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 38   25.0        4.0          98.0         NaN  2046.0          19.0
# 133  21.0        6.0         200.0         NaN  2875.0          17.0
# 337  40.9        4.0          85.0         NaN  1835.0          17.3
# 343  23.6        4.0         140.0         NaN  2905.0          14.3
# 361  34.5        4.0         100.0         NaN  2320.0          15.8
# 382  23.0        4.0         151.0         NaN  3035.0          20.5
#
#      model year  origin              car name
# 38         71.0     1.0            ford pinto
# 133        74.0     1.0         ford maverick
# 337        80.0     2.0  renault lecar deluxe
# 343        80.0     1.0    ford mustang cobra
# 361        81.0     2.0           renault 18i
# 382        82.0     1.0        amc concord dl

# %%
# Fill the null values of "horsepower" with the mean of "horsepower".
ds['horsepower'] = ds['horsepower'].fillna(ds['horsepower'].median())

# %%
# Remove rows from the data set with a null values.
new_ds = ds.dropna()

# %%
# Information about the new "clean" data set.
new_ds.info()

# Display the shape of the data.
print("\nThe new data frame has {} rows and {} columns.".format(
    new_ds.shape[0], new_ds.shape[1]))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 398 entries, 0 to 405
# Data columns (total 9 columns):
# mpg             398 non-null float64
# cylinders       398 non-null float64
# displacement    398 non-null float64
# horsepower      398 non-null float64
# weight          398 non-null float64
# acceleration    398 non-null float64
# model year      398 non-null float64
# origin          398 non-null float64
# car name        398 non-null object
# dtypes: float64(8), object(1)
# memory usage: 31.1+ KB
#
# The new data frame has 398 rows and 9 columns.

# %%
# Statistics for the new data set.
new_ds.describe().transpose()
# Out:
#               count         mean         std     min       25%     50%  \
# mpg           398.0    23.514573    7.815984     9.0    17.500    23.0
# cylinders     398.0     5.454774    1.701004     3.0     4.000     4.0
# displacement  398.0   193.425879  104.269838    68.0   104.250   148.5
# horsepower    398.0   104.326633   38.216655    46.0    76.000    95.0
# weight        398.0  2970.424623  846.841774  1613.0  2223.750  2803.5
# acceleration  398.0    15.568090    2.757689     8.0    13.825    15.5
# model year    398.0    76.010050    3.697627    70.0    73.000    76.0
# origin        398.0     1.572864    0.802055     1.0     1.000     1.0
#
#                    75%     max
# mpg             29.000    46.6
# cylinders        8.000     8.0
# displacement   262.000   455.0
# horsepower     125.000   230.0
# weight        3608.000  5140.0
# acceleration    17.175    24.8
# model year      79.000    82.0
# origin           2.000     3.0

# %%
# Plotting a pairplot for the new data set.
plt.figure(figsize=(20, 20))
sns.set(font_scale=1.1)
sns.pairplot(data=new_ds, diag_kind='kde', hue='origin')
plt.show()

# %%
# Plotting a correlation heatmap for the new data set.
corr = new_ds[['mpg','displacement','horsepower','weight','acceleration']].corr()
plt.figure(figsize=(8, 8))
sns.set(font_scale=1.1)
sns.heatmap(data=corr, annot=True, cbar=False, cmap='rainbow', linewidth=0.5)
plt.title('Correlation Matrix')
plt.show()

# %%
corrs = new_ds[['mpg', 'displacement',
                'horsepower', 'weight', 'acceleration']].corr()
figure = ff.create_annotated_heatmap(
    z=corrs.values,
    x=list(corrs.columns),
    y=list(corrs.index),
    annotation_text=corrs.round(2).values,
    showscale=True, colorscale=[[0.0, "rgb(165,0,38)"],
                                [0.1111111111111111, "rgb(215,48,39)"],
                                [0.2222222222222222, "rgb(244,109,67)"],
                                [0.3333333333333333, "rgb(253,174,97)"],
                                [0.4444444444444444, "rgb(254,224,144)"],
                                [0.5555555555555556, "rgb(224,243,248)"],
                                [0.6666666666666666, "rgb(171,217,233)"],
                                [0.7777777777777778, "rgb(116,173,209)"],
                                [0.8888888888888888, "rgb(69,117,180)"],
                                [1.0, "rgb(49,54,149)"]])
figure.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-04fca7c514b0> in <module>
# ----> 1 corrs = new_ds[['mpg', 'displacement',
#       2                 'horsepower', 'weight', 'acceleration']].corr()
#       3 figure = ff.create_annotated_heatmap(
#       4     z=corrs.values,
#       5     x=list(corrs.columns),
#
# NameError: name 'new_ds' is not defined

# %% [markdown]
# ## Part 2: Preproccesing
# In this part we prepare the data for our models. This means that we choose the columns that will be our independed variables and which column the target that we want to predict. Once we are done with that, we split our data into train and test sets and perfom a standardization upon them.

# %%
# Distinguish attribute columns and target column.
X = new_ds[new_ds.columns[1:-1]]
y = new_ds['mpg']

# %%
# Split to train and test sets.
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=25)

# %%
# Standardization
scaler = StandardScaler()
scaler.fit(X_train)
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# ## Part 3: Modeling
# In this section we build and try 3 models:
# - Linear Regression
# - Decision tree
# - Neural network
#
# Each model will be trained and make a prediction for the test set. Accuracy, precision, recall, f1-score, confusion matrix and ROC will be calculated for each model. Then we will use the GridSearchCV module to tune our models and search for the best hyperparameters in order to increase the accuracy of each model.

# %%
# Score metrics
scores = ['neg_mean_absolute_error', 'neg_mean_squared_error']

# %% [markdown]
# ## Linear Regression

# %%
# Initialize a Logistic Regression estimator.
linreg = LinearRegression(n_jobs=-1)

# Train the estimator.
linreg.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=-1, normalize=False)

# %%
# Make predictions.
lin_pred = linreg.predict(X_test)

# Calculate CV.
cv_lin_reg = cross_validate(linreg, X, y, scoring=scores, cv=10, n_jobs=-1)

# %% [markdown]
# ## Linear Regression Metrics

# %%
# Mean absolute error (average error).
print("Mean absolute error (MAE): %.2f" %
      mean_absolute_error(y_test, lin_pred))

# Mean squared error (relative error).
print("Mean squared error (MSE): %.2f" % mean_squared_error(y_test, lin_pred))

# Mean root squared error (relative error).
print("Mean root squared error (RMSE): %.2f" %
      np.sqrt(mean_squared_error(y_test, lin_pred)))

# Cross-Validation MAE
print('Cross-validation MAE: %0.2f' %
      (abs(cv_lin_reg['test_neg_mean_absolute_error'].mean())))

# Cross-Validation MSE
print('Cross-validation MSE: %.2f' %
      (abs(cv_lin_reg['test_neg_mean_squared_error'].mean())))

# Cross-Validation MSE
print('Cross-validation RMSE: %.2f' %
      (np.sqrt(abs(cv_lin_reg['test_neg_mean_squared_error'].mean()))))
# Out:
# Mean absolute error (MAE): 2.57
# Mean squared error (MSE): 11.29
# Mean root squared error (RMSE): 3.36
# Cross-validation MAE: 2.75
# Cross-validation MSE: 12.90
# Cross-validation RMSE: 3.59

# %% [markdown]
# ## Decision tree

# %%
# Initialize a decision tree estimator.
tr = tree.DecisionTreeRegressor(max_depth=30, random_state=25)

# Train the estimator.
tr.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(ccp_alpha=0.0, criterion='mse', max_depth=30,
#                       max_features=None, max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, presort='deprecated',
#                       random_state=25, splitter='best')

# %%
# Plot the tree.
fig = plt.figure(figsize=(23, 15))
tree.plot_tree(tr.fit(X_train, y_train), feature_names=X.columns,
               filled=True, rounded=True, fontsize=16)
plt.title('Decision Tree')
# Out:
# Text(0.5, 1.0, 'Decision Tree')

# %%
# Print the tree in a simplified version.
r = tree.export_text(tr, feature_names=X.columns.tolist())
print(r)
# Out:
# |--- displacement <= 0.00
# |   |--- weight <= -0.91
# |   |   |--- model year <= 0.46
# |   |   |   |--- weight <= -1.11
# |   |   |   |   |--- weight <= -1.35
# |   |   |   |   |   |--- origin <= 1.18
# |   |   |   |   |   |   |--- value: [36.00]
# |   |   |   |   |   |--- origin >  1.18
# |   |   |   |   |   |   |--- weight <= -1.58
# |   |   |   |   |   |   |   |--- value: [35.00]
# |   |   |   |   |   |   |--- weight >  -1.58
# |   |   |   |   |   |   |   |--- weight <= -1.41
# |   |   |   |   |   |   |   |   |--- value: [31.00]
# |   |   |   |   |   |   |   |--- weight >  -1.41
# |   |   |   |   |   |   |   |   |--- value: [33.00]
# |   |   |   |   |--- weight >  -1.35
# |   |   |   |   |   |--- origin <= 1.18
# |   |   |   |   |   |   |--- weight <= -1.18
# |   |   |   |   |   |   |   |--- acceleration <= -0.24
# |   |   |   |   |   |   |   |   |--- value: [29.00]
# |   |   |   |   |   |   |   |--- acceleration >  -0.24
# |   |   |   |   |   |   |   |   |--- horsepower <= -1.08
# |   |   |   |   |   |   |   |   |   |--- value: [27.00]
# |   |   |   |   |   |   |   |   |--- horsepower >  -1.08
# |   |   |   |   |   |   |   |   |   |--- value: [26.00]
# |   |   |   |   |   |   |--- weight >  -1.18
# |   |   |   |   |   |   |   |--- acceleration <= 1.31
# |   |   |   |   |   |   |   |   |--- value: [31.00]
# |   |   |   |   |   |   |   |--- acceleration >  1.31
# |   |   |   |   |   |   |   |   |--- value: [29.00]
# |   |   |   |   |   |--- origin >  1.18
# |   |   |   |   |   |   |--- horsepower <= -0.94
# |   |   |   |   |   |   |   |--- acceleration <= 0.71
# |   |   |   |   |   |   |   |   |--- value: [30.00]
# |   |   |   |   |   |   |   |--- acceleration >  0.71
# |   |   |   |   |   |   |   |   |--- horsepower <= -1.02
# |   |   |   |   |   |   |   |   |   |--- value: [32.00]
# |   |   |   |   |   |   |   |   |--- horsepower >  -1.02
# |   |   |   |   |   |   |   |   |   |--- model year <= -0.08
# |   |   |   |   |   |   |   |   |   |   |--- value: [31.00]
# |   |   |   |   |   |   |   |   |   |--- model year >  -0.08
# |   |   |   |   |   |   |   |   |   |   |--- value: [31.50]
# |   |   |   |   |   |   |--- horsepower >  -0.94
# |   |   |   |   |   |   |   |--- value: [33.50]
# |   |   |   |--- weight >  -1.11
# |   |   |   |   |--- acceleration <= -0.09
# |   |   |   |   |   |--- model year <= -0.08
# |   |   |   |   |   |   |--- displacement <= -1.02
# |   |   |   |   |   |   |   |--- value: [30.00]
# |   |   |   |   |   |   |--- displacement >  -1.02
# |   |   |   |   |   |   |   |--- origin <= 1.18
# |   |   |   |   |   |   |   |   |--- value: [28.00]
# |   |   |   |   |   |   |   |--- origin >  1.18
# |   |   |   |   |   |   |   |   |--- value: [27.00]
# |   |   |   |   |   |--- model year >  -0.08
# |   |   |   |   |   |   |--- displacement <= -0.88
# |   |   |   |   |   |   |   |--- value: [30.50]
# |   |   |   |   |   |   |--- displacement >  -0.88
# |   |   |   |   |   |   |   |--- value: [30.00]
# |   |   |   |   |--- acceleration >  -0.09
# |   |   |   |   |   |--- displacement <= -1.06
# |   |   |   |   |   |   |--- value: [30.00]
# |   |   |   |   |   |--- displacement >  -1.06
# |   |   |   |   |   |   |--- origin <= 1.18
# |   |   |   |   |   |   |   |--- weight <= -0.96
# |   |   |   |   |   |   |   |   |--- horsepower <= -0.73
# |   |   |   |   |   |   |   |   |   |--- horsepower <= -0.98
# |   |   |   |   |   |   |   |   |   |   |--- value: [24.50]
# |   |   |   |   |   |   |   |   |   |--- horsepower >  -0.98
# |   |   |   |   |   |   |   |   |   |   |--- value: [24.00]
# |   |   |   |   |   |   |   |   |--- horsepower >  -0.73
# |   |   |   |   |   |   |   |   |   |--- value: [25.00]
# |   |   |   |   |   |   |   |--- weight >  -0.96
# |   |   |   |   |   |   |   |   |--- value: [26.00]
# |   |   |   |   |   |   |--- origin >  1.18
# |   |   |   |   |   |   |   |--- value: [29.00]
# |   |   |--- model year >  0.46
# |   |   |   |--- horsepower <= -1.30
# |   |   |   |   |--- horsepower <= -1.42
# |   |   |   |   |   |--- value: [44.30]
# |   |   |   |   |--- horsepower >  -1.42
# |   |   |   |   |   |--- value: [44.00]
# |   |   |   |--- horsepower >  -1.30
# |   |   |   |   |--- displacement <= -1.03
# |   |   |   |   |   |--- weight <= -1.08
# |   |   |   |   |   |   |--- model year <= 1.01
# |   |   |   |   |   |   |   |--- displacement <= -1.05
# |   |   |   |   |   |   |   |   |--- value: [31.80]
# |   |   |   |   |   |   |   |--- displacement >  -1.05
# |   |   |   |   |   |   |   |   |--- value: [34.10]
# |   |   |   |   |   |   |--- model year >  1.01
# |   |   |   |   |   |   |   |--- acceleration <= 0.27
# |   |   |   |   |   |   |   |   |--- value: [35.10]
# |   |   |   |   |   |   |   |--- acceleration >  0.27
# |   |   |   |   |   |   |   |   |--- weight <= -1.24
# |   |   |   |   |   |   |   |   |   |--- model year <= 1.28
# |   |   |   |   |   |   |   |   |   |   |--- value: [40.90]
# |   |   |   |   |   |   |   |   |   |--- model year >  1.28
# |   |   |   |   |   |   |   |   |   |   |--- displacement <= -1.08
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [39.10]
# |   |   |   |   |   |   |   |   |   |   |--- displacement >  -1.08
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [39.00]
# |   |   |   |   |   |   |   |   |--- weight >  -1.24
# |   |   |   |   |   |   |   |   |   |--- value: [37.00]
# |   |   |   |   |   |--- weight >  -1.08
# |   |   |   |   |   |   |--- displacement <= -1.05
# |   |   |   |   |   |   |   |--- value: [40.80]
# |   |   |   |   |   |   |--- displacement >  -1.05
# |   |   |   |   |   |   |   |--- value: [46.60]
# |   |   |   |   |--- displacement >  -1.03
# |   |   |   |   |   |--- horsepower <= -0.78
# |   |   |   |   |   |   |--- horsepower <= -1.14
# |   |   |   |   |   |   |   |--- displacement <= -1.01
# |   |   |   |   |   |   |   |   |--- value: [38.10]
# |   |   |   |   |   |   |   |--- displacement >  -1.01
# |   |   |   |   |   |   |   |   |--- value: [36.10]
# |   |   |   |   |   |   |--- horsepower >  -1.14
# |   |   |   |   |   |   |   |--- displacement <= -1.01
# |   |   |   |   |   |   |   |   |--- weight <= -1.29
# |   |   |   |   |   |   |   |   |   |--- value: [29.80]
# |   |   |   |   |   |   |   |   |--- weight >  -1.29
# |   |   |   |   |   |   |   |   |   |--- model year <= 0.73
# |   |   |   |   |   |   |   |   |   |   |--- value: [31.50]
# |   |   |   |   |   |   |   |   |   |--- model year >  0.73
# |   |   |   |   |   |   |   |   |   |   |--- value: [31.90]
# |   |   |   |   |   |   |   |--- displacement >  -1.01
# |   |   |   |   |   |   |   |   |--- acceleration <= -0.06
# |   |   |   |   |   |   |   |   |   |--- horsepower <= -0.93
# |   |   |   |   |   |   |   |   |   |   |--- model year <= 1.28
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [37.30]
# |   |   |   |   |   |   |   |   |   |   |--- model year >  1.28
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [38.00]
# |   |   |   |   |   |   |   |   |   |--- horsepower >  -0.93
# |   |   |   |   |   |   |   |   |   |   |--- weight <= -0.94
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [33.00]
# |   |   |   |   |   |   |   |   |   |   |--- weight >  -0.94
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- acceleration >  -0.06
# |   |   |   |   |   |   |   |   |   |--- model year <= 1.55
# |   |   |   |   |   |   |   |   |   |   |--- origin <= 0.55
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [34.40]
# |   |   |   |   |   |   |   |   |   |   |--- origin >  0.55
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- model year >  1.55
# |   |   |   |   |   |   |   |   |   |   |--- horsepower <= -0.98
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [32.00]
# |   |   |   |   |   |   |   |   |   |   |--- horsepower >  -0.98
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [31.00]
# |   |   |   |   |   |--- horsepower >  -0.78
# |   |   |   |   |   |   |--- horsepower <= -0.74
# |   |   |   |   |   |   |   |--- value: [41.50]
# |   |   |   |   |   |   |--- horsepower >  -0.74
# |   |   |   |   |   |   |   |--- displacement <= -0.94
# |   |   |   |   |   |   |   |   |--- value: [34.30]
# |   |   |   |   |   |   |   |--- displacement >  -0.94
# |   |   |   |   |   |   |   |   |--- value: [35.70]
# |   |--- weight >  -0.91
# |   |   |--- model year <= 0.73
# |   |   |   |--- weight <= -0.27
# |   |   |   |   |--- acceleration <= 1.04
# |   |   |   |   |   |--- horsepower <= -0.34
# |   |   |   |   |   |   |--- displacement <= -0.84
# |   |   |   |   |   |   |   |--- model year <= 0.46
# |   |   |   |   |   |   |   |   |--- weight <= -0.91
# |   |   |   |   |   |   |   |   |   |--- value: [29.00]
# |   |   |   |   |   |   |   |   |--- weight >  -0.91
# |   |   |   |   |   |   |   |   |   |--- model year <= -1.31
# |   |   |   |   |   |   |   |   |   |   |--- value: [24.00]
# |   |   |   |   |   |   |   |   |   |--- model year >  -1.31
# |   |   |   |   |   |   |   |   |   |   |--- horsepower <= -0.60
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- horsepower >  -0.60
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |--- model year >  0.46
# |   |   |   |   |   |   |   |   |--- value: [30.90]
# |   |   |   |   |   |   |--- displacement >  -0.84
# |   |   |   |   |   |   |   |--- displacement <= -0.63
# |   |   |   |   |   |   |   |   |--- model year <= -0.77
# |   |   |   |   |   |   |   |   |   |--- displacement <= -0.77
# |   |   |   |   |   |   |   |   |   |   |--- value: [25.00]
# |   |   |   |   |   |   |   |   |   |--- displacement >  -0.77
# |   |   |   |   |   |   |   |   |   |   |--- model year <= -1.18
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [23.00]
# |   |   |   |   |   |   |   |   |   |   |--- model year >  -1.18
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [22.00]
# |   |   |   |   |   |   |   |   |--- model year >  -0.77
# |   |   |   |   |   |   |   |   |   |--- displacement <= -0.74
# |   |   |   |   |   |   |   |   |   |   |--- value: [25.00]
# |   |   |   |   |   |   |   |   |   |--- displacement >  -0.74
# |   |   |   |   |   |   |   |   |   |   |--- value: [26.00]
# |   |   |   |   |   |   |   |--- displacement >  -0.63
# |   |   |   |   |   |   |   |   |--- model year <= -0.90
# |   |   |   |   |   |   |   |   |   |--- value: [28.00]
# |   |   |   |   |   |   |   |   |--- model year >  -0.90
# |   |   |   |   |   |   |   |   |   |--- horsepower <= -0.83
# |   |   |   |   |   |   |   |   |   |   |--- value: [26.50]
# |   |   |   |   |   |   |   |   |   |--- horsepower >  -0.83
# |   |   |   |   |   |   |   |   |   |   |--- displacement <= -0.49
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 3
# |   |   |   |   |   |   |   |   |   |   |--- displacement >  -0.49
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [24.50]
# |   |   |   |   |   |--- horsepower >  -0.34
# |   |   |   |   |   |   |--- cylinders <= -1.16
# |   |   |   |   |   |   |   |--- weight <= -0.56
# |   |   |   |   |   |   |   |   |--- value: [19.00]
# |   |   |   |   |   |   |   |--- weight >  -0.56
# |   |   |   |   |   |   |   |   |--- value: [21.50]
# |   |   |   |   |   |   |--- cylinders >  -1.16
# |   |   |   |   |   |   |   |--- weight <= -0.73
# |   |   |   |   |   |   |   |   |--- origin <= 1.18
# |   |   |   |   |   |   |   |   |   |--- model year <= -0.63
# |   |   |   |   |   |   |   |   |   |   |--- value: [25.00]
# |   |   |   |   |   |   |   |   |   |--- model year >  -0.63
# |   |   |   |   |   |   |   |   |   |   |--- value: [25.50]
# |   |   |   |   |   |   |   |   |--- origin >  1.18
# |   |   |   |   |   |   |   |   |   |--- acceleration <= -0.37
# |   |   |   |   |   |   |   |   |   |   |--- value: [25.00]
# |   |   |   |   |   |   |   |   |   |--- acceleration >  -0.37
# |   |   |   |   |   |   |   |   |   |   |--- value: [24.00]
# |   |   |   |   |   |   |   |--- weight >  -0.73
# |   |   |   |   |   |   |   |   |--- acceleration <= -0.42
# |   |   |   |   |   |   |   |   |   |--- horsepower <= -0.28
# |   |   |   |   |   |   |   |   |   |   |--- value: [27.50]
# |   |   |   |   |   |   |   |   |   |--- horsepower >  -0.28
# |   |   |   |   |   |   |   |   |   |   |--- weight <= -0.44
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [21.50]
# |   |   |   |   |   |   |   |   |   |   |--- weight >  -0.44
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [24.00]
# |   |   |   |   |   |   |   |   |--- acceleration >  -0.42
# |   |   |   |   |   |   |   |   |   |--- horsepower <= -0.26
# |   |   |   |   |   |   |   |   |   |   |--- origin <= 1.18
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [23.00]
# |   |   |   |   |   |   |   |   |   |   |--- origin >  1.18
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- horsepower >  -0.26
# |   |   |   |   |   |   |   |   |   |   |--- weight <= -0.59
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- weight >  -0.59
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |--- acceleration >  1.04
# |   |   |   |   |   |--- horsepower <= -0.59
# |   |   |   |   |   |   |--- model year <= -0.49
# |   |   |   |   |   |   |   |--- model year <= -0.90
# |   |   |   |   |   |   |   |   |--- origin <= -0.08
# |   |   |   |   |   |   |   |   |   |--- value: [22.00]
# |   |   |   |   |   |   |   |   |--- origin >  -0.08
# |   |   |   |   |   |   |   |   |   |--- value: [23.00]
# |   |   |   |   |   |   |   |--- model year >  -0.90
# |   |   |   |   |   |   |   |   |--- value: [21.00]
# |   |   |   |   |   |   |--- model year >  -0.49
# |   |   |   |   |   |   |   |--- value: [23.00]
# |   |   |   |   |   |--- horsepower >  -0.59
# |   |   |   |   |   |   |--- value: [20.00]
# |   |   |   |--- weight >  -0.27
# |   |   |   |   |--- horsepower <= -0.26
# |   |   |   |   |   |--- model year <= -0.90
# |   |   |   |   |   |   |--- weight <= -0.12
# |   |   |   |   |   |   |   |--- value: [22.00]
# |   |   |   |   |   |   |--- weight >  -0.12
# |   |   |   |   |   |   |   |--- value: [21.00]
# |   |   |   |   |   |--- model year >  -0.90
# |   |   |   |   |   |   |--- horsepower <= -0.42
# |   |   |   |   |   |   |   |--- value: [23.80]
# |   |   |   |   |   |   |--- horsepower >  -0.42
# |   |   |   |   |   |   |   |--- value: [23.00]
# |   |   |   |   |--- horsepower >  -0.26
# |   |   |   |   |   |--- weight <= -0.19
# |   |   |   |   |   |   |--- cylinders <= -0.59
# |   |   |   |   |   |   |   |--- value: [21.60]
# |   |   |   |   |   |   |--- cylinders >  -0.59
# |   |   |   |   |   |   |   |--- model year <= -0.08
# |   |   |   |   |   |   |   |   |--- value: [20.00]
# |   |   |   |   |   |   |   |--- model year >  -0.08
# |   |   |   |   |   |   |   |   |--- value: [20.30]
# |   |   |   |   |   |--- weight >  -0.19
# |   |   |   |   |   |   |--- acceleration <= 0.25
# |   |   |   |   |   |   |   |--- acceleration <= -0.18
# |   |   |   |   |   |   |   |   |--- value: [18.00]
# |   |   |   |   |   |   |   |--- acceleration >  -0.18
# |   |   |   |   |   |   |   |   |--- weight <= 0.03
# |   |   |   |   |   |   |   |   |   |--- value: [19.00]
# |   |   |   |   |   |   |   |   |--- weight >  0.03
# |   |   |   |   |   |   |   |   |   |--- value: [20.00]
# |   |   |   |   |   |   |--- acceleration >  0.25
# |   |   |   |   |   |   |   |--- value: [16.50]
# |   |   |--- model year >  0.73
# |   |   |   |--- origin <= -0.08
# |   |   |   |   |--- weight <= -0.73
# |   |   |   |   |   |--- value: [36.00]
# |   |   |   |   |--- weight >  -0.73
# |   |   |   |   |   |--- weight <= -0.36
# |   |   |   |   |   |   |--- weight <= -0.66
# |   |   |   |   |   |   |   |--- displacement <= -0.76
# |   |   |   |   |   |   |   |   |--- value: [29.90]
# |   |   |   |   |   |   |   |--- displacement >  -0.76
# |   |   |   |   |   |   |   |   |--- value: [30.00]
# |   |   |   |   |   |   |--- weight >  -0.66
# |   |   |   |   |   |   |   |--- model year <= 1.28
# |   |   |   |   |   |   |   |   |--- displacement <= -0.58
# |   |   |   |   |   |   |   |   |   |--- value: [27.40]
# |   |   |   |   |   |   |   |   |--- displacement >  -0.58
# |   |   |   |   |   |   |   |   |   |--- cylinders <= -0.30
# |   |   |   |   |   |   |   |   |   |   |--- weight <= -0.39
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [28.40]
# |   |   |   |   |   |   |   |   |   |   |--- weight >  -0.39
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [28.00]
# |   |   |   |   |   |   |   |   |   |--- cylinders >  -0.30
# |   |   |   |   |   |   |   |   |   |   |--- value: [28.80]
# |   |   |   |   |   |   |   |--- model year >  1.28
# |   |   |   |   |   |   |   |   |--- displacement <= -0.51
# |   |   |   |   |   |   |   |   |   |--- horsepower <= -0.52
# |   |   |   |   |   |   |   |   |   |   |--- weight <= -0.58
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [27.20]
# |   |   |   |   |   |   |   |   |   |   |--- weight >  -0.58
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |--- horsepower >  -0.52
# |   |   |   |   |   |   |   |   |   |   |--- value: [27.00]
# |   |   |   |   |   |   |   |   |--- displacement >  -0.51
# |   |   |   |   |   |   |   |   |   |--- acceleration <= -0.02
# |   |   |   |   |   |   |   |   |   |   |--- weight <= -0.47
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [26.00]
# |   |   |   |   |   |   |   |   |   |   |--- weight >  -0.47
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [25.80]
# |   |   |   |   |   |   |   |   |   |--- acceleration >  -0.02
# |   |   |   |   |   |   |   |   |   |   |--- value: [26.60]
# |   |   |   |   |   |--- weight >  -0.36
# |   |   |   |   |   |   |--- acceleration <= -0.42
# |   |   |   |   |   |   |   |--- weight <= -0.23
# |   |   |   |   |   |   |   |   |--- value: [23.50]
# |   |   |   |   |   |   |   |--- weight >  -0.23
# |   |   |   |   |   |   |   |   |--- value: [23.60]
# |   |   |   |   |   |   |--- acceleration >  -0.42
# |   |   |   |   |   |   |   |--- weight <= -0.02
# |   |   |   |   |   |   |   |   |--- horsepower <= 0.02
# |   |   |   |   |   |   |   |   |   |--- acceleration <= 0.13
# |   |   |   |   |   |   |   |   |   |   |--- value: [27.90]
# |   |   |   |   |   |   |   |   |   |--- acceleration >  0.13
# |   |   |   |   |   |   |   |   |   |   |--- horsepower <= -0.44
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [26.40]
# |   |   |   |   |   |   |   |   |   |   |--- horsepower >  -0.44
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [27.00]
# |   |   |   |   |   |   |   |   |--- horsepower >  0.02
# |   |   |   |   |   |   |   |   |   |--- value: [25.00]
# |   |   |   |   |   |   |   |--- weight >  -0.02
# |   |   |   |   |   |   |   |   |--- value: [23.00]
# |   |   |   |--- origin >  -0.08
# |   |   |   |   |--- cylinders <= -1.16
# |   |   |   |   |   |--- value: [23.70]
# |   |   |   |   |--- cylinders >  -1.16
# |   |   |   |   |   |--- weight <= 0.19
# |   |   |   |   |   |   |--- acceleration <= 1.55
# |   |   |   |   |   |   |   |--- weight <= -0.51
# |   |   |   |   |   |   |   |   |--- origin <= 1.18
# |   |   |   |   |   |   |   |   |   |--- displacement <= -0.81
# |   |   |   |   |   |   |   |   |   |   |--- value: [34.50]
# |   |   |   |   |   |   |   |   |   |--- displacement >  -0.81
# |   |   |   |   |   |   |   |   |   |   |--- value: [35.00]
# |   |   |   |   |   |   |   |   |--- origin >  1.18
# |   |   |   |   |   |   |   |   |   |--- model year <= 1.55
# |   |   |   |   |   |   |   |   |   |   |--- weight <= -0.84
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [32.20]
# |   |   |   |   |   |   |   |   |   |   |--- weight >  -0.84
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [32.40]
# |   |   |   |   |   |   |   |   |   |--- model year >  1.55
# |   |   |   |   |   |   |   |   |   |   |--- value: [34.00]
# |   |   |   |   |   |   |   |--- weight >  -0.51
# |   |   |   |   |   |   |   |   |--- acceleration <= -0.29
# |   |   |   |   |   |   |   |   |   |--- horsepower <= 0.19
# |   |   |   |   |   |   |   |   |   |   |--- value: [32.00]
# |   |   |   |   |   |   |   |   |   |--- horsepower >  0.19
# |   |   |   |   |   |   |   |   |   |   |--- value: [32.70]
# |   |   |   |   |   |   |   |   |--- acceleration >  -0.29
# |   |   |   |   |   |   |   |   |   |--- model year <= 1.28
# |   |   |   |   |   |   |   |   |   |   |--- value: [29.80]
# |   |   |   |   |   |   |   |   |   |--- model year >  1.28
# |   |   |   |   |   |   |   |   |   |   |--- horsepower <= -0.79
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [31.60]
# |   |   |   |   |   |   |   |   |   |   |--- horsepower >  -0.79
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [30.70]
# |   |   |   |   |   |   |--- acceleration >  1.55
# |   |   |   |   |   |   |   |--- value: [36.40]
# |   |   |   |   |   |--- weight >  0.19
# |   |   |   |   |   |   |--- acceleration <= 2.59
# |   |   |   |   |   |   |   |--- value: [28.10]
# |   |   |   |   |   |   |--- acceleration >  2.59
# |   |   |   |   |   |   |   |--- value: [27.20]
# |--- displacement >  0.00
# |   |--- horsepower <= 0.21
# |   |   |--- model year <= 1.55
# |   |   |   |--- model year <= -0.08
# |   |   |   |   |--- acceleration <= 0.45
# |   |   |   |   |   |--- weight <= 0.35
# |   |   |   |   |   |   |--- horsepower <= -0.04
# |   |   |   |   |   |   |   |--- weight <= -0.38
# |   |   |   |   |   |   |   |   |--- value: [21.00]
# |   |   |   |   |   |   |   |--- weight >  -0.38
# |   |   |   |   |   |   |   |   |--- weight <= 0.11
# |   |   |   |   |   |   |   |   |   |--- model year <= -0.63
# |   |   |   |   |   |   |   |   |   |   |--- value: [18.00]
# |   |   |   |   |   |   |   |   |   |--- model year >  -0.63
# |   |   |   |   |   |   |   |   |   |   |--- value: [19.00]
# |   |   |   |   |   |   |   |   |--- weight >  0.11
# |   |   |   |   |   |   |   |   |   |--- value: [19.00]
# |   |   |   |   |   |   |--- horsepower >  -0.04
# |   |   |   |   |   |   |   |--- acceleration <= -0.46
# |   |   |   |   |   |   |   |   |--- value: [20.00]
# |   |   |   |   |   |   |   |--- acceleration >  -0.46
# |   |   |   |   |   |   |   |   |--- value: [21.00]
# |   |   |   |   |   |--- weight >  0.35
# |   |   |   |   |   |   |--- model year <= -0.90
# |   |   |   |   |   |   |   |--- displacement <= 0.37
# |   |   |   |   |   |   |   |   |--- value: [16.00]
# |   |   |   |   |   |   |   |--- displacement >  0.37
# |   |   |   |   |   |   |   |   |--- value: [17.00]
# |   |   |   |   |   |   |--- model year >  -0.90
# |   |   |   |   |   |   |   |--- value: [18.00]
# |   |   |   |   |--- acceleration >  0.45
# |   |   |   |   |   |--- displacement <= 0.39
# |   |   |   |   |   |   |--- value: [17.00]
# |   |   |   |   |   |--- displacement >  0.39
# |   |   |   |   |   |   |--- model year <= -0.36
# |   |   |   |   |   |   |   |--- model year <= -0.63
# |   |   |   |   |   |   |   |   |--- value: [16.00]
# |   |   |   |   |   |   |   |--- model year >  -0.63
# |   |   |   |   |   |   |   |   |--- weight <= 0.63
# |   |   |   |   |   |   |   |   |   |--- value: [15.00]
# |   |   |   |   |   |   |   |   |--- weight >  0.63
# |   |   |   |   |   |   |   |   |   |--- value: [16.00]
# |   |   |   |   |   |   |--- model year >  -0.36
# |   |   |   |   |   |   |   |--- value: [15.00]
# |   |   |   |--- model year >  -0.08
# |   |   |   |   |--- displacement <= 0.99
# |   |   |   |   |   |--- weight <= 0.50
# |   |   |   |   |   |   |--- horsepower <= -0.59
# |   |   |   |   |   |   |   |--- value: [24.00]
# |   |   |   |   |   |   |--- horsepower >  -0.59
# |   |   |   |   |   |   |   |--- acceleration <= 1.80
# |   |   |   |   |   |   |   |   |--- acceleration <= 0.80
# |   |   |   |   |   |   |   |   |   |--- model year <= 0.19
# |   |   |   |   |   |   |   |   |   |   |--- acceleration <= 0.36
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [22.00]
# |   |   |   |   |   |   |   |   |   |   |--- acceleration >  0.36
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [22.50]
# |   |   |   |   |   |   |   |   |   |--- model year >  0.19
# |   |   |   |   |   |   |   |   |   |   |--- displacement <= 0.31
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |   |--- displacement >  0.31
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |--- acceleration >  0.80
# |   |   |   |   |   |   |   |   |   |--- acceleration <= 0.91
# |   |   |   |   |   |   |   |   |   |   |--- value: [17.50]
# |   |   |   |   |   |   |   |   |   |--- acceleration >  0.91
# |   |   |   |   |   |   |   |   |   |   |--- acceleration <= 1.07
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- acceleration >  1.07
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [19.10]
# |   |   |   |   |   |   |   |--- acceleration >  1.80
# |   |   |   |   |   |   |   |   |--- value: [23.90]
# |   |   |   |   |   |--- weight >  0.50
# |   |   |   |   |   |   |--- cylinders <= 0.83
# |   |   |   |   |   |   |   |--- weight <= 0.55
# |   |   |   |   |   |   |   |   |--- value: [17.60]
# |   |   |   |   |   |   |   |--- weight >  0.55
# |   |   |   |   |   |   |   |   |--- acceleration <= 1.31
# |   |   |   |   |   |   |   |   |   |--- displacement <= 0.37
# |   |   |   |   |   |   |   |   |   |   |--- model year <= 0.46
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [19.00]
# |   |   |   |   |   |   |   |   |   |   |--- model year >  0.46
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [18.60]
# |   |   |   |   |   |   |   |   |   |--- displacement >  0.37
# |   |   |   |   |   |   |   |   |   |   |--- value: [18.50]
# |   |   |   |   |   |   |   |   |--- acceleration >  1.31
# |   |   |   |   |   |   |   |   |   |--- value: [19.20]
# |   |   |   |   |   |   |--- cylinders >  0.83
# |   |   |   |   |   |   |   |--- value: [17.00]
# |   |   |   |   |--- displacement >  0.99
# |   |   |   |   |   |--- value: [26.60]
# |   |   |--- model year >  1.55
# |   |   |   |--- value: [38.00]
# |   |--- horsepower >  0.21
# |   |   |--- model year <= 0.46
# |   |   |   |--- weight <= 1.53
# |   |   |   |   |--- weight <= 0.60
# |   |   |   |   |   |--- weight <= 0.33
# |   |   |   |   |   |   |--- displacement <= 1.68
# |   |   |   |   |   |   |   |--- value: [13.00]
# |   |   |   |   |   |   |--- displacement >  1.68
# |   |   |   |   |   |   |   |--- value: [14.00]
# |   |   |   |   |   |--- weight >  0.33
# |   |   |   |   |   |   |--- weight <= 0.48
# |   |   |   |   |   |   |   |--- value: [16.00]
# |   |   |   |   |   |   |--- weight >  0.48
# |   |   |   |   |   |   |   |--- value: [18.00]
# |   |   |   |   |--- weight >  0.60
# |   |   |   |   |   |--- weight <= 1.28
# |   |   |   |   |   |   |--- horsepower <= 1.78
# |   |   |   |   |   |   |   |--- acceleration <= -1.37
# |   |   |   |   |   |   |   |   |--- model year <= -0.90
# |   |   |   |   |   |   |   |   |   |--- model year <= -1.31
# |   |   |   |   |   |   |   |   |   |   |--- acceleration <= -2.37
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [14.00]
# |   |   |   |   |   |   |   |   |   |   |--- acceleration >  -2.37
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [15.00]
# |   |   |   |   |   |   |   |   |   |--- model year >  -1.31
# |   |   |   |   |   |   |   |   |   |   |--- value: [17.00]
# |   |   |   |   |   |   |   |   |--- model year >  -0.90
# |   |   |   |   |   |   |   |   |   |--- value: [14.00]
# |   |   |   |   |   |   |   |--- acceleration >  -1.37
# |   |   |   |   |   |   |   |   |--- horsepower <= 0.46
# |   |   |   |   |   |   |   |   |   |--- value: [15.50]
# |   |   |   |   |   |   |   |   |--- horsepower >  0.46
# |   |   |   |   |   |   |   |   |   |--- model year <= -0.36
# |   |   |   |   |   |   |   |   |   |   |--- weight <= 1.00
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [15.00]
# |   |   |   |   |   |   |   |   |   |   |--- weight >  1.00
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 4
# |   |   |   |   |   |   |   |   |   |--- model year >  -0.36
# |   |   |   |   |   |   |   |   |   |   |--- value: [13.00]
# |   |   |   |   |   |   |--- horsepower >  1.78
# |   |   |   |   |   |   |   |--- value: [11.00]
# |   |   |   |   |   |--- weight >  1.28
# |   |   |   |   |   |   |--- model year <= -0.90
# |   |   |   |   |   |   |   |--- acceleration <= -0.28
# |   |   |   |   |   |   |   |   |--- weight <= 1.30
# |   |   |   |   |   |   |   |   |   |--- value: [15.00]
# |   |   |   |   |   |   |   |   |--- weight >  1.30
# |   |   |   |   |   |   |   |   |   |--- weight <= 1.51
# |   |   |   |   |   |   |   |   |   |   |--- model year <= -1.18
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [14.00]
# |   |   |   |   |   |   |   |   |   |   |--- model year >  -1.18
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [13.00]
# |   |   |   |   |   |   |   |   |   |--- weight >  1.51
# |   |   |   |   |   |   |   |   |   |   |--- value: [15.00]
# |   |   |   |   |   |   |   |--- acceleration >  -0.28
# |   |   |   |   |   |   |   |   |--- value: [13.00]
# |   |   |   |   |   |   |--- model year >  -0.90
# |   |   |   |   |   |   |   |--- horsepower <= 0.90
# |   |   |   |   |   |   |   |   |--- displacement <= 0.98
# |   |   |   |   |   |   |   |   |   |--- value: [16.00]
# |   |   |   |   |   |   |   |   |--- displacement >  0.98
# |   |   |   |   |   |   |   |   |   |--- value: [17.50]
# |   |   |   |   |   |   |   |--- horsepower >  0.90
# |   |   |   |   |   |   |   |   |--- acceleration <= -1.55
# |   |   |   |   |   |   |   |   |   |--- value: [16.00]
# |   |   |   |   |   |   |   |   |--- acceleration >  -1.55
# |   |   |   |   |   |   |   |   |   |--- model year <= -0.36
# |   |   |   |   |   |   |   |   |   |   |--- value: [14.00]
# |   |   |   |   |   |   |   |   |   |--- model year >  -0.36
# |   |   |   |   |   |   |   |   |   |   |--- horsepower <= 1.12
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |   |   |   |   |   |   |   |--- horsepower >  1.12
# |   |   |   |   |   |   |   |   |   |   |   |--- truncated branch of depth 2
# |   |   |   |--- weight >  1.53
# |   |   |   |   |--- model year <= -0.36
# |   |   |   |   |   |--- horsepower <= 2.14
# |   |   |   |   |   |   |--- displacement <= 1.26
# |   |   |   |   |   |   |   |--- value: [14.00]
# |   |   |   |   |   |   |--- displacement >  1.26
# |   |   |   |   |   |   |   |--- weight <= 1.63
# |   |   |   |   |   |   |   |   |--- acceleration <= -1.19
# |   |   |   |   |   |   |   |   |   |--- value: [14.00]
# |   |   |   |   |   |   |   |   |--- acceleration >  -1.19
# |   |   |   |   |   |   |   |   |   |--- value: [13.00]
# |   |   |   |   |   |   |   |--- weight >  1.63
# |   |   |   |   |   |   |   |   |--- weight <= 2.11
# |   |   |   |   |   |   |   |   |   |--- weight <= 1.79
# |   |   |   |   |   |   |   |   |   |   |--- displacement <= 1.65
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [12.00]
# |   |   |   |   |   |   |   |   |   |   |--- displacement >  1.65
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [13.00]
# |   |   |   |   |   |   |   |   |   |--- weight >  1.79
# |   |   |   |   |   |   |   |   |   |   |--- value: [13.00]
# |   |   |   |   |   |   |   |   |--- weight >  2.11
# |   |   |   |   |   |   |   |   |   |--- acceleration <= -0.91
# |   |   |   |   |   |   |   |   |   |   |--- weight <= 2.33
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [12.00]
# |   |   |   |   |   |   |   |   |   |   |--- weight >  2.33
# |   |   |   |   |   |   |   |   |   |   |   |--- value: [13.00]
# |   |   |   |   |   |   |   |   |   |--- acceleration >  -0.91
# |   |   |   |   |   |   |   |   |   |   |--- value: [11.00]
# |   |   |   |   |   |--- horsepower >  2.14
# |   |   |   |   |   |   |--- acceleration <= -0.64
# |   |   |   |   |   |   |   |--- acceleration <= -1.83
# |   |   |   |   |   |   |   |   |--- value: [14.00]
# |   |   |   |   |   |   |   |--- acceleration >  -1.83
# |   |   |   |   |   |   |   |   |--- weight <= 2.04
# |   |   |   |   |   |   |   |   |   |--- value: [11.00]
# |   |   |   |   |   |   |   |   |--- weight >  2.04
# |   |   |   |   |   |   |   |   |   |--- value: [12.00]
# |   |   |   |   |   |   |--- acceleration >  -0.64
# |   |   |   |   |   |   |   |--- horsepower <= 2.26
# |   |   |   |   |   |   |   |   |--- value: [9.00]
# |   |   |   |   |   |   |   |--- horsepower >  2.26
# |   |   |   |   |   |   |   |   |--- value: [10.00]
# |   |   |   |   |--- model year >  -0.36
# |   |   |   |   |   |--- horsepower <= 1.03
# |   |   |   |   |   |   |--- value: [15.00]
# |   |   |   |   |   |--- horsepower >  1.03
# |   |   |   |   |   |   |--- horsepower <= 1.72
# |   |   |   |   |   |   |   |--- value: [16.00]
# |   |   |   |   |   |   |--- horsepower >  1.72
# |   |   |   |   |   |   |   |--- value: [16.50]
# |   |   |--- model year >  0.46
# |   |   |   |--- weight <= 1.13
# |   |   |   |   |--- acceleration <= -0.80
# |   |   |   |   |   |--- acceleration <= -1.28
# |   |   |   |   |   |   |--- value: [18.10]
# |   |   |   |   |   |--- acceleration >  -1.28
# |   |   |   |   |   |   |--- displacement <= 0.98
# |   |   |   |   |   |   |   |--- value: [20.20]
# |   |   |   |   |   |   |--- displacement >  0.98
# |   |   |   |   |   |   |   |--- displacement <= 1.31
# |   |   |   |   |   |   |   |   |--- displacement <= 1.05
# |   |   |   |   |   |   |   |   |   |--- value: [19.20]
# |   |   |   |   |   |   |   |   |--- displacement >  1.05
# |   |   |   |   |   |   |   |   |   |--- value: [19.40]
# |   |   |   |   |   |   |   |--- displacement >  1.31
# |   |   |   |   |   |   |   |   |--- value: [18.50]
# |   |   |   |   |--- acceleration >  -0.80
# |   |   |   |   |   |--- acceleration <= -0.46
# |   |   |   |   |   |   |--- value: [17.60]
# |   |   |   |   |   |--- acceleration >  -0.46
# |   |   |   |   |   |   |--- horsepower <= 0.53
# |   |   |   |   |   |   |   |--- value: [18.10]
# |   |   |   |   |   |   |--- horsepower >  0.53
# |   |   |   |   |   |   |   |--- value: [18.20]
# |   |   |   |--- weight >  1.13
# |   |   |   |   |--- displacement <= 1.42
# |   |   |   |   |   |--- displacement <= 1.26
# |   |   |   |   |   |   |--- value: [17.50]
# |   |   |   |   |   |--- displacement >  1.26
# |   |   |   |   |   |   |--- value: [16.90]
# |   |   |   |   |--- displacement >  1.42
# |   |   |   |   |   |--- value: [15.50]

# %%
# Make predictions.
tr_pred = tr.predict(X_test)

# Calculate CV.
cv_tr_reg = cross_validate(tr, X, y, scoring=scores, cv=10, n_jobs=-1)

# %% [markdown]
# ## Decision tree Metrics

# %%
# Mean absolute error (average error).
print("Mean absolute error (MAE): %.2f" %
      mean_absolute_error(y_test, tr_pred))

# Mean squared error (relative error).
print("Mean squared error (MSE): %.2f" % mean_squared_error(y_test, tr_pred))

# Mean root squared error (relative error).
print("Mean root squared error (RMSE): %.2f" %
      np.sqrt(mean_squared_error(y_test, tr_pred)))

# Cross-Validation MAE
print('Cross-validation MAE: %0.2f' %
      (abs(cv_tr_reg['test_neg_mean_absolute_error'].mean())))

# Cross-Validation MSE
print('Cross-validation MSE: %.2f' %
      (abs(cv_tr_reg['test_neg_mean_squared_error'].mean())))

# Cross-Validation MSE
print('Cross-validation RMSE: %.2f' %
      (np.sqrt(abs(cv_tr_reg['test_neg_mean_squared_error'].mean()))))
# Out:
# Mean absolute error (MAE): 2.37
# Mean squared error (MSE): 12.70
# Mean root squared error (RMSE): 3.56
# Cross-validation MAE: 2.91
# Cross-validation MSE: 16.14
# Cross-validation RMSE: 4.02

# %% [markdown]
# ## Neural network (MLP)

# %%
# Initialize a Multi-layer Perceptron classifier.
mlp = MLPRegressor(max_iter=1000, random_state=25, shuffle=True, verbose=False)

# Train the classifier.
mlp.fit(X_train, y_train)
# Out:
# MLPRegressor(activation='relu', alpha=0.0001, batch_size='auto', beta_1=0.9,
#              beta_2=0.999, early_stopping=False, epsilon=1e-08,
#              hidden_layer_sizes=(100,), learning_rate='constant',
#              learning_rate_init=0.001, max_fun=15000, max_iter=1000,
#              momentum=0.9, n_iter_no_change=10, nesterovs_momentum=True,
#              power_t=0.5, random_state=25, shuffle=True, solver='adam',
#              tol=0.0001, validation_fraction=0.1, verbose=False,
#              warm_start=False)

# %%
# Make predictions.
mlp_pred = mlp.predict(X_test)

# Calculate CV
cv_mlp_reg = cross_validate(mlp, X, y, scoring=scores, cv=10, n_jobs=-1)

# %% [markdown]
# ## Neural network (MLP) metrics

# %%
# Mean absolute error (average error).
print("Mean absolute error (MAE): %.2f" %
      mean_absolute_error(y_test, mlp_pred))

# Mean squared error (relative error).
print("Mean squared error (MSE): %.2f" % mean_squared_error(y_test, mlp_pred))

# Mean root squared error (relative error).
print("Mean root squared error (RMSE): %.2f" %
      np.sqrt(mean_squared_error(y_test, mlp_pred)))

# Cross-Validation MAE
print('Cross-validation MAE: %0.2f' %
      (abs(cv_mlp_reg['test_neg_mean_absolute_error'].mean())))

# Cross-Validation MSE
print('Cross-validation MSE: %.2f' %
      (abs(cv_mlp_reg['test_neg_mean_squared_error'].mean())))

# Cross-Validation MSE
print('Cross-validation RMSE: %.2f' %
      (np.sqrt(abs(cv_mlp_reg['test_neg_mean_squared_error'].mean()))))
# Out:
# Mean absolute error (MAE): 1.75
# Mean squared error (MSE): 6.88
# Mean root squared error (RMSE): 2.62
# Cross-validation MAE: 2.80
# Cross-validation MSE: 14.25
# Cross-validation RMSE: 3.78

# %% [markdown]
# ## Results

# %%
metrics = ['MAE', 'MSE', 'RMSE', 'CV MAE', 'CV MSE', 'CV RMSE']

# Plot metrics.
fig = go.Figure(data=[
    go.Bar(name='Linear Regression', x=metrics, y=[mean_absolute_error(y_test, lin_pred),
                                                   mean_squared_error(
                                                       y_test, lin_pred),
                                                   np.sqrt(mean_squared_error(
                                                       y_test, lin_pred)),
                                                   abs(cv_lin_reg['test_neg_mean_absolute_error'].mean(
                                                   )),
                                                   abs(cv_lin_reg['test_neg_mean_squared_error'].mean(
                                                   )),
                                                   np.sqrt(abs(cv_lin_reg['test_neg_mean_squared_error'].mean()))]),
    go.Bar(name='Decision Tree', x=metrics, y=[mean_absolute_error(y_test, tr_pred),
                                               mean_squared_error(
        y_test, tr_pred),
        np.sqrt(mean_squared_error(
            y_test, tr_pred)),
        abs(cv_tr_reg['test_neg_mean_absolute_error'].mean(
        )),
        abs(cv_tr_reg['test_neg_mean_squared_error'].mean(
        )),
        np.sqrt(abs(cv_tr_reg['test_neg_mean_squared_error'].mean()))]),
    go.Bar(name='Neural Network (MLP)', x=metrics, y=[mean_absolute_error(y_test, mlp_pred),
                                                      mean_squared_error(
        y_test, mlp_pred),
        np.sqrt(mean_squared_error(
            y_test, mlp_pred)),
        abs(cv_mlp_reg['test_neg_mean_absolute_error'].mean(
        )),
        abs(cv_mlp_reg['test_neg_mean_squared_error'].mean(
        )),
        np.sqrt(abs(cv_mlp_reg['test_neg_mean_squared_error'].mean()))])
])

fig.update_layout(title_text='Results',
                  barmode='group', xaxis_tickangle=-45, bargroupgap=0.05)
fig.show()
# Out:
# <div>
#
#
#             <div id="cbfc2bff-5595-4015-9e41-86925bd7c668" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("cbfc2bff-5595-4015-9e41-86925bd7c668")) {
#                     Plotly.newPlot(
#                         'cbfc2bff-5595-4015-9e41-86925bd7c668',
#                         [{"name": "Linear Regression", "type": "bar", "x": ["MAE", "MSE", "RMSE", "CV MAE", "CV MSE", "CV RMSE"], "y": [2.569990663960865, 11.286091081576659, 3.3594777989408797, 2.7483879518882106, 12.901928055879603, 3.5919253967586244]}, {"name": "Decision Tree", "type": "bar", "x": ["MAE", "MSE", "RMSE", "CV MAE", "CV MSE", "CV RMSE"], "y": [2.368333333333333, 12.703333333333337, 3.5641735835019785, 2.9142628205128203, 16.136371153846152, 4.017010225758225]}, {"name": "Neural Network (MLP)", "type": "bar", "x": ["MAE", "MSE", "RMSE", "CV MAE", "CV MSE", "CV RMSE"], "y": [1.7520129034259009, 6.876351814492608, 2.6222798886641767, 2.8022457836210446, 14.254843509001157, 3.775558701570028]}],
#                         {"bargroupgap": 0.05, "barmode": "group", "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "sca ...

# %%
d = {
    'Models': ['Linear Regression', 'Decision Tree', 'Neural Network (MLP)'],
    'MAE': [mean_absolute_error(y_test, lin_pred), mean_absolute_error(y_test, tr_pred), mean_absolute_error(y_test, mlp_pred)],
    'MSE': [mean_squared_error(y_test, lin_pred), mean_squared_error(y_test, tr_pred), mean_squared_error(y_test, mlp_pred)],
    'RMSE': np.sqrt([mean_squared_error(y_test, lin_pred), mean_squared_error(y_test, tr_pred), mean_squared_error(y_test, mlp_pred)]),
    'CV MAE': [abs(cv_lin_reg['test_neg_mean_absolute_error'].mean()), abs(cv_tr_reg['test_neg_mean_absolute_error'].mean()), abs(cv_mlp_reg['test_neg_mean_absolute_error'].mean())],
    'CV MSE': [abs(cv_lin_reg['test_neg_mean_squared_error'].mean()), abs(cv_tr_reg['test_neg_mean_squared_error'].mean()), abs(cv_mlp_reg['test_neg_mean_squared_error'].mean())],
    'CV RMSE': np.sqrt([abs(cv_lin_reg['test_neg_mean_squared_error'].mean()), abs(cv_tr_reg['test_neg_mean_squared_error'].mean()), abs(cv_mlp_reg['test_neg_mean_squared_error'].mean())])

}

results = pd.DataFrame(data=d).round(3).set_index('Models')
results
# Out:
#                         MAE     MSE   RMSE  CV MAE  CV MSE  CV RMSE
# Models
# Linear Regression     2.570  11.286  3.359   2.748  12.902    3.592
# Decision Tree         2.368  12.703  3.564   2.914  16.136    4.017
# Neural Network (MLP)  1.752   6.876  2.622   2.802  14.255    3.776

# %% [markdown]
# ## Quinlan's results
#
# |                   | Mean squared error (MSE) | Mean absolute error (MAE) |
# |-------------------|:------------------------:|:-------------------------:|
# | Linear Regression |           19.4           |            2.61           |
# | Decision tree     |           14.7           |            2.11           |
# | Neural Network    |           12.5           |            2.02           |

# %% [markdown]
# ## Evaluating Performance
#
# ### Hypothesis Testing
# - $H_{0}$: There is no significant difference in the test set error rate of two supervised learner models $M_{1}$ and $M_{2}$ built with the same training data.
# - $H_{1}$: There is significant difference in the test set error rate of two supervised learner models $M_{1}$ and $M_{2}$ built with the same training data.
#
# ### Comparing models with a single test set
#
# **Step 1.** (Initialization). Given:
# - Two models, $M_{1}$ and $M_{2}$ built with the same training data.
# - One test set $A$ with $card(A)=n$.
# - Mean Absolute Error $mae_{1}$ for model $M_{1}$ on test set $A$.
# - Mean Absolute Error $mae_{2}$ for model $M_{2}$ on test set $A$.
#
# **Step 2.** Compute:
#
# $$P=\frac{|mae_{1}-mae_{2}|}{\sqrt{\frac{(v_{1}+v_{2})}{n}}}$$
#
# **Step 3.** Conclude:
# If $P≥2$, hypothesis $H_{1}$ holds. Otherwise, $H_{0}$ is true.

# %%
from itertools import combinations

# Dictionary with all the Regressors.
models = {'LinearRegression': linreg,
          'DecisionTreeRegressor': tr,
          'MLPRegressor': mlp
          }


def evaluating_performance(models=None):
    if models == None:
        return 'No models to compare'
    else:
        for model in combinations(models.keys(), 2):
            mae1 = mean_absolute_error(
                y_test, models[model[0]].predict(X_test))
            mae2 = mean_absolute_error(
                y_test, models[model[1]].predict(X_test))
            var1 = np.var(models[model[0]].predict(X_test))
            var2 = np.var(models[model[1]].predict(X_test))
            n = len(X_test)
            P = abs(mae1-mae2)/np.sqrt((var1+var2)/n)
            print(
                f'Comparing Performance between {model[0]} and {model[1]}:', P.round(3))
            if P < 2:
                print(
                    f'There is no significant diferrence between {model[0]} and {model[1]}\n')
            else:
                print(
                    f'The models {model[0]} and {model[1]} are significant different')

# %%
evaluating_performance(models)
# Out:
# Comparing Performance between LinearRegression and DecisionTreeRegressor: 0.221
# There is no significant diferrence between LinearRegression and DecisionTreeRegressor
#
# Comparing Performance between LinearRegression and MLPRegressor: 0.932
# There is no significant diferrence between LinearRegression and MLPRegressor
#
# Comparing Performance between DecisionTreeRegressor and MLPRegressor: 0.643
# There is no significant diferrence between DecisionTreeRegressor and MLPRegressor

# %% [markdown]
# ---
